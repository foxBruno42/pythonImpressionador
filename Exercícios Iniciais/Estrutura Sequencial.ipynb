# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print("Alo mundo")
# Out:
# Alo mundo

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
num = input("Insira um número\n")
print(f"O número informado foi {num}")
# Out:
# O número informado foi 10

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
num = int(input("Insira um número"))
num2 = int(input("Insira outro número"))
print(num+num2)
# Out:
# 9

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %%
n1 = float(input("Insira sua N1:"))
n2 = float(input("Insina sua N2:"))
n3 = float(input("Insina sua N3:"))
n4 = float(input("Insina sua N4:"))
print((n1+n2+n3+n4)/4)
# Out:
# 7.0

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
m = float(input("Insira uma medida em metros?"))
print(f"A medida informada em centrimetros é: {int(m*100)}")
# Out:
# A medida informada em centrimetros é: 14725

# %% [markdown]
# #### 6. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
l = float(input("Digite a largura da sua sala em metros:"))
a = float(input("Digite a altura da sua sala em metros:"))
print(f"A área total de sua sala é {(l*a)}")
# Out:
# A área total de sua sala é 24.75

# %% [markdown]
# #### 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
hr=int(input("Quantas horas você trabalha por mês?"))
vl=float(input("Quanto você ganha por hora?"))
print(f"O Seu salário baseado nessas informações é de R$ {(hr*vl)}")
# Out:
# O Seu salário baseado nessas informações é de R$ 6812.9

# %% [markdown]
# #### 8. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
fah = float(input("Quantos graus fahrenheit está agora?"))
print(f"A temperatura em CELSIUS é de {(5.0/9.0*(fah-32.0))}c")
# Out:
# A temperatura em CELSIUS é de 33.333333333333336c

# %% [markdown]
# #### 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
cel = float(input("Quantos graus Celsius está agora?"))
print(f"A temperatura em Fahrenheit é de {(((9/5)*cel)+32.0)} fah")
# Out:
# A temperatura em Fahrenheit é de 91.99994000000001 fah

# %% [markdown]
# #### 10. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
h=float(input("Por favor, me informe sua altura"))
print(f"Seu peso ideal é: {(72.7*h-58)}")
# Out:
# Seu peso ideal é: 68.498

# %% [markdown]
# #### 11. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
h=float(input("Por favor, me informe sua altura"))
print(f"Se você é homem seu peso ideal é: {(72.7*h-58)}")
print(f"Se você é mulher seu peso ideal é: {(62.1*h-44.7)}")
# Out:
# Se você é homem seu peso ideal é: 57.593
# Se você é mulher seu peso ideal é: 54.039

# %% [markdown]
# #### 12. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
vlhr=float(input("Quanto você ganha por hora?"))
hrtb=int(input("Quantas horas você trabalha por mês?"))

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
bruto = vlhr*hrtb
print(f"O Seu salário bruto é de R$ {bruto}")
# Out:
# O Seu salário bruto é de R$ 6709.5

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
ir = bruto*0.11
print(f"Seu imposto de renda é de R$ {ir}")
# Out:
# Seu imposto de renda é de R$ 738.045

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
inss = bruto*0.08
print(f"O valor do INSS é de R$ {inss}")
# Out:
# O valor do INSS é de R$ 536.76

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
sind = bruto*0.05
print(f"A contribuição do sindicato é de R$ {sind}")
# Out:
# A contribuição do sindicato é de R$ 335.475

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
print(f"Seu salário liquído é de R$ {(bruto-ir-inss-sind)}")
# Out:
# Seu salário liquído é de R$ 5099.219999999999

# %% [markdown]
# #### 13. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
m = float(input("Insira o tamanho da área que precisa ser pintada:"))
ml=3*18
print(f"Quantidade de latas necessárias {(m/ml)}")
print(f"Valor a ser pago pelas latas R$ {(m/ml)*80.0}")
# Out:
# Quantidade de latas necessárias 8.983333333333334
# Valor a ser pago pelas latas R$ 718.6666666666667

# %% [markdown]
# #### 14. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
MB = float(input("Insira o tamanho do seu arquivo em MB:"))
Mb = float(input("Qual a velocidade do seu link de internet?"))
print(f"O tempo estimado para download é de {MB/(Mb*8)} minuto(s)")
# Out:
# O tempo estimado para download é de 12.125 minuto(s)
